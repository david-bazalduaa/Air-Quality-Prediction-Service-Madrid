# %%
import sys
from pathlib import Path

def is_google_colab() -> bool:
    if "google.colab" in str(get_ipython()):
        return True
    return False

def clone_repository() -> None:
    # !git clone https://github.com/featurestorebook/mlfs-book.git
    # %cd mlfs-book

def install_dependencies() -> None:
    # !pip install --upgrade uv
    # !uv pip install --all-extras --system --requirement pyproject.toml

if is_google_colab():
    clone_repository()
    install_dependencies()
    root_dir = str(Path().absolute())
    print("Google Colab environment")
else:
    root_dir = Path().absolute()
    # Strip ~/notebooks/ccfraud from PYTHON_PATH if notebook started in one of these subdirectories
    if root_dir.parts[-1:] == ('airquality',):
        root_dir = Path(*root_dir.parts[:-1])
    if root_dir.parts[-1:] == ('notebooks',):
        root_dir = Path(*root_dir.parts[:-1])
    root_dir = str(root_dir) 
    print("Local environment")

# Add the root directory to the `PYTHONPATH` to use the `recsys` Python module from the notebook.
if root_dir not in sys.path:
    sys.path.append(root_dir)
print(f"Added the following directory to the PYTHONPATH: {root_dir}")
    
# Set the environment variables from the file <root_dir>/.env
from mlfs import config
settings = config.HopsworksSettings(_env_file=f"{root_dir}/.env")
# Out:
# Local environment
# Added the following directory to the PYTHONPATH: /Users/davidbazalduamendez/Documents/GitHub/Air-Quality-Prediction-Service-Solna
# HopsworksSettings initialized!

# %% [markdown]
# <span style="font-width:bold; font-size: 3rem; color:#333;">- Part 02: Daily Feature Pipeline for Air Quality (aqicn.org) and weather (openmeteo)</span>
#
# ## 🗒️ This notebook is divided into the following sections:
# 1. Download and Parse Data
# 2. Feature Group Insertion
#
#
# __This notebook should be scheduled to run daily__
#
# In the book, we use a GitHub Action stored here:
# [.github/workflows/air-quality-daily.yml](https://github.com/featurestorebook/mlfs-book/blob/main/.github/workflows/air-quality-daily.yml)
#
# However, you are free to use any Python Orchestration tool to schedule this program to run daily.

# %% [markdown]
# ### <span style='color:#ff5f27'> 📝 Imports

# %%
import datetime
import time
import requests
import pandas as pd
import hopsworks
from mlfs.airquality import util_2
from mlfs import config
import json
import os
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## <span style='color:#ff5f27'> 🌍 Get the Sensor URL, Country, City, Street names from Hopsworks </span>
#
# __Update the values in the cell below.__
#
# __These should be the same values as in notebook 1 - the feature backfill notebook__

# %%
project = hopsworks.login(engine="python")
fs = project.get_feature_store()
secrets = hopsworks.get_secrets_api()

AQICN_API_KEY = secrets.get_secret("AQICN_API_KEY").value

sensors_json = secrets.get_secret("SENSORS_MADRID_JSON").value
SENSORS = json.loads(sensors_json)

today = datetime.date.today()

SENSORS

location_str = secrets.get_secret("SENSOR_LOCATION_JSON").value

location = json.loads(location_str)

location
# Out:
# 2025-11-17 20:55:37,997 INFO: Initializing external client
# 2025-11-17 20:55:37,997 INFO: Base URL: https://c.app.hopsworks.ai:443
# 2025-11-17 20:55:39,599 INFO: Python Engine initialized.
#
# Logged in to project, explore it here https://c.app.hopsworks.ai:443/p/1271984
# {'country': 'spain',
#  'city': 'madrid',
#  'street': 'castellana',
#  'aqicn_url': 'https://api.waqi.info/feed/@3231',
#  'latitude': '40.4397',
#  'longitude': '-3.6882'}

# %% [markdown]
# ### <span style="color:#ff5f27;"> 🔮 Get references to the Feature Groups </span>

# %%
# Retrieve feature groups
air_quality_fg = fs.get_feature_group(
    name="air_quality_madrid",
    version=1
)

weather_fg = fs.get_feature_group(
    name="weather_madrid_sensors",
    version=1
)

# %% [markdown]
# ---

# %% [markdown]
# ## <span style='color:#ff5f27'> 🌫 Retrieve Today's Air Quality data (PM2.5) from the AQI API</span>

# %%
SENSORS[0], SENSORS[0].keys()
# Out:
# ({'sensor_id': 'casa_de_campo',
#   'csv_file': 'casa-de-campo-air-quality.csv',
#   'city': 'madrid',
#   'country': 'spain',
#   'street': 'casa-de-campo',
#   'latitude': 40.42,
#   'longitude': -3.753,
#   'url': 'https://api.waqi.info/feed/@3228'},
#  dict_keys(['sensor_id', 'csv_file', 'city', 'country', 'street', 'latitude', 'longitude', 'url']))

# %%
all_rows = []

for sensor in SENSORS:

    try:
        df = util_2.get_pm25(
            sensor["url"],
            sensor["country"],
            sensor["city"],
            sensor["street"],
            today,
            AQICN_API_KEY
        )

        df["sensor_id"] = sensor["sensor_id"]

        all_rows.append(df)

        print(f"OK → {sensor['street']}")

    except Exception as e:
        print(f"ERROR → {sensor['street']}: {e}")

# merge all dataframes
aq_today_df = pd.concat(all_rows, ignore_index=True)

# Assign proper data types
aq_today_df["date"] = pd.to_datetime(aq_today_df["date"])
aq_today_df["pm25"] = aq_today_df["pm25"].astype("float64")  # o float32 si tu FG lo tiene así

# Select only the columns needed for insertion
aq_today_df = aq_today_df[["date", "pm25", "sensor_id", "city", "country", "street"]]
aq_today_df.head()
# Out:
# OK → casa-de-campo
# OK → castellana
# OK → cuatro-caminos
# OK → escuelas-aguirre
# OK → fernandez-ladreda
# OK → mendez-alvaro
# OK → plaza-de-castilla
#         date  pm25          sensor_id    city country             street
# 0 2025-11-17  17.0      casa_de_campo  madrid   spain      casa-de-campo
# 1 2025-11-17  34.0         castellana  madrid   spain         castellana
# 2 2025-11-17  38.0     cuatro_caminos  madrid   spain     cuatro-caminos
# 3 2025-11-17  30.0   escuelas_aguirre  madrid   spain   escuelas-aguirre
# 4 2025-11-17  59.0  fernandez_ladreda  madrid   spain  fernandez-ladreda

# %%
aq_today_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   date       7 non-null      datetime64[ns]
#  1   pm25       7 non-null      float64
#  2   sensor_id  7 non-null      object
#  3   city       7 non-null      object
#  4   country    7 non-null      object
#  5   street     7 non-null      object
# dtypes: datetime64[ns](1), float64(1), object(4)
# memory usage: 464.0+ bytes

# %% [markdown]
# ## <span style='color:#ff5f27'> 🌦 Get Weather Forecast data</span>

# %%
from mlfs.airquality.util_2 import get_hourly_weather_forecast
weather_rows = []

for sensor in SENSORS:
    try:
        hourly_df = get_hourly_weather_forecast(
            sensor["city"],
            sensor["latitude"],
            sensor["longitude"]
        )
        hourly_df = hourly_df.set_index("date")

        daily_df = hourly_df.between_time("11:59", "12:01").reset_index()

        daily_df["date"] = pd.to_datetime(daily_df["date"]).dt.date
        daily_df["date"] = pd.to_datetime(daily_df["date"])

        daily_df["sensor_id"] = sensor["sensor_id"]
        daily_df["city"] = sensor["city"]
        daily_df["country"] = sensor["country"]
        daily_df["street"] = sensor["street"]

        weather_rows.append(daily_df)

        print(f"OK forecast → {sensor['street']}")

    except Exception as e:
        print(f"ERROR forecast → {sensor['street']}: {e}")

weather_forecast_df = pd.concat(weather_rows, ignore_index=True)
# Out:
# Coordinates: 40.5°N -3.75°E
# Elevation: 649.0 m asl
# Timezone difference to GMT+0: 0s
# OK forecast → casa-de-campo
# Coordinates: 40.5°N -3.75°E
# Elevation: 698.0 m asl
# Timezone difference to GMT+0: 0s
# OK forecast → castellana
# Coordinates: 40.5°N -3.75°E
# Elevation: 708.0 m asl
# Timezone difference to GMT+0: 0s
# OK forecast → cuatro-caminos
# Coordinates: 40.5°N -3.75°E
# Elevation: 695.0 m asl
# Timezone difference to GMT+0: 0s
# OK forecast → escuelas-aguirre
# Coordinates: 40.5°N -3.75°E
# Elevation: 639.0 m asl
# Timezone difference to GMT+0: 0s
# OK forecast → fernandez-ladreda
# Coordinates: 40.5°N -3.75°E
# Elevation: 606.0 m asl
# Timezone difference to GMT+0: 0s
# OK forecast → mendez-alvaro
# Coordinates: 40.5°N -3.75°E
# Elevation: 749.0 m asl
# Timezone difference to GMT+0: 0s
# OK forecast → plaza-de-castilla

# %%
weather_forecast_df.sort_values('date', inplace=True)
weather_forecast_df
# Out:
#          date  temperature_2m_mean  precipitation_sum  wind_speed_10m_max  \
# 0  2025-11-17                12.50                0.0            3.219938
# 21 2025-11-17                12.20                0.0            3.219938
# 28 2025-11-17                12.60                0.0            3.219938
# 42 2025-11-17                11.85                0.0            3.219938
# 7  2025-11-17                12.20                0.0            3.219938
# 35 2025-11-17                12.80                0.0            3.219938
# 14 2025-11-17                12.15                0.0            3.219938
# 1  2025-11-18                11.10                0.0            1.609969
# 29 2025-11-18                11.20                0.0            1.609969
# 43 2025-11-18                10.45                0.0            1.609969
# 8  2025-11-18                10.80                0.0            1.609969
# 22 2025-11-18                10.80                0.0            1.609969
# 36 2025-11-18                11.40                0.0            1.609969
# 15 2025-11-18                10.75                0.0            1.609969
# 30 2025-11-19                 9.45                0.0            3.960000
# 16 2025-11-19                 9.00                0.0            3.960000
# 37 2025-11-19                 9.65                0.0            3.960000
# 9  2025-11-19                 9.05                0.0            3.960000
# 44 2025-11-19                 8.70                0.0            3.960000
# 2  2025-11-19                 9.35                0.0            3.960000
# 23 2025-11-19                 9.05                0.0            3.960000
# 31 2025-11-20                 7.95                0.1            4.349896
# 45 2025-11-20                 7.20                0.1            4.349896
# 38 2025-11-20                 8.15                0.1            4.349896
# 24 2025-11-20                 7.55                0.1            4.349896
# 3  2025-11-20                 7.85                0.1            4.349896
# 17 2025-11-20                 7.50                0.1            4.349896
# 10 2025-11-20                 7.55                0.1            4.349896
# 25 2025-11-21                 5.25                0.0            5.400000
# 46 2025-11-21                 4.90                0.0            5.400000
# 4  2025-11-21                 5.55                0.0            5.400000
# 18 2025-11-21                 5.20                0.0            5.400000
# 32 2025-11-21                 5.65                0.0            5.400000
# 39 2025-11-21                 5.85                0.0            5.400000
# 11 2025-11-21                 5.25                0.0            5.400000
# 5  2025-11-22                 5.55                0.0            7.235910
# 40 2025-11-22                 5.85                0.0            7.235910
# 12 2025-11-22                 5.25                0.0            7.235910
# 33 2025-11-22                 5.65                0.0            7.235910
# 19 2025-11-22                 5.20                0.0            7.235910
# 26 2025-11-22                 5.25                0.0            7.235910
# 47 2025-11-22                 4.90                0.0            7.235910
# 13 2025-11-23                11.25                0.1           15.646544
# 34 2025-11-23                11.65                0.1           15.646544
# 41 2025-11-23                11.85                0.1           15.646544
# 6  2025-11-23                11.55                0.1           15.646544
# 20 2025-11-23                11.20                0.1           15.646544
# 27 2025-11-23                11.25                0.1           15.646544
# 48 2025-11-23                10.90                0.1           15.646544
#
#     wind_direction_10m_dominant  cloud_cover_max  relative_humidity_2m_mean  \
# 0                     63.435013             24.0                       77.0
# 21                    63.435013             24.0                       77.0
# 28                    63.435013             24.0                       77.0
# 42                    63.435013             24.0                       77.0
# 7                     63.435013             24.0                       77.0
# 35                    63.435013             24.0                       77.0
# 14                    63.435013             24.0                       77.0
# 1                    206.564987              0.0                       65.0
# 29                   206.564987              0.0                       65.0
# 43                   206.564987              0.0                       65.0
# 8                    206.564987              0.0                       65.0
# 22                   206.564987              0.0                       65.0
# 36                   206.564987              0.0                       65.0
# 15                   206.564987              0.0                       65.0
# 30                    90.000000             30.0                       59.0
# 16                    90.000000             30.0                       59.0
# 37                    90.000000             30.0                       59.0
# 9                     90.000000             30.0                       59.0
# 44                    90.000000             30.0                       59.0
# 2                     90.000000             30.0                       59.0
# 23                    90.000000             30.0                       59.0
# 31                   335.556061              9.0                       64.0
# 45                   335.556061              9.0                       64.0
# 38                   335.556061              9.0                       64.0
# 24                   335.556061              9.0                       64.0
# 3                    335.556061              9.0                       64.0
# 17                   335.556061              9.0                       64.0
# 10                   335.556061              9.0                       64.0
# 25                   216.869980              0.0                       48.0
# 46                   216.869980              0.0                       48.0
# 4                    216.869980              0.0                       48.0
# 18                   216.869980              0.0                       48.0
# 32                   216.869980              0.0                       48.0
# 39                   216.869980              0.0                       48.0
# 11                   216.869980              0.0                       48.0
# 5                    264.289490             90.0                       61.0
# 40                   264.289490             90.0                       61.0
# 12                   264.289490             90.0                       61.0
# 33                   264.289490             90.0                       61.0
# 19                   264.289490             90.0                       61.0
# 26                   264.289490             90.0                       61.0
# 47                   264.289490             90.0                       61.0
# 13                   293.025513             95.0                       61.0
# 34                   293.025513             95.0                       61.0
# 41                   293.025513             95.0                       61.0
# 6                    293.025513             95.0                       61.0
# 20                   293.025513             95.0                       61.0
# 27                   293.025513             95.0                       61.0
# 48                   293.025513             95.0                       61.0
#
#     dew_point_2m_max          sensor_id    city country             street
# 0           8.576816      casa_de_campo  madrid   spain      casa-de-campo
# 21          8.285951   escuelas_aguirre  madrid   spain   escuelas-aguirre
# 28          8.673769  fernandez_ladreda  madrid   spain  fernandez-ladreda
# 42          7.946596     plaza_castilla  madrid   spain  plaza-de-castilla
# 7           8.285951         castellana  madrid   spain         castellana
# 35          8.867671      mendez_alvaro  madrid   spain      mendez-alvaro
# 14          8.237471     cuatro_caminos  madrid   spain     cuatro-caminos
# 1           4.766593      casa_de_campo  madrid   spain      casa-de-campo
# 29          4.861669  fernandez_ladreda  madrid   spain  fernandez-ladreda
# 43          4.148546     plaza_castilla  madrid   spain  plaza-de-castilla
# 8           4.481350         castellana  madrid   spain         castellana
# 22          4.481350   escuelas_aguirre  madrid   spain   escuelas-aguirre
# 36          5.051817      mendez_alvaro  madrid   spain      mendez-alvaro
# 15          4.433808     cuatro_caminos  madrid   spain     cuatro-caminos
# 30          1.834259  fernandez_ladreda  madrid   spain  fernandez-ladreda
# 16          1.410973     cuatro_caminos  madrid   spain     cuatro-caminos
# 37          2.022370      mendez_alvaro  madrid   spain      mendez-alvaro
# 9           1.458007         castellana  madrid   spain         castellana
# 44          1.128757     plaza_castilla  madrid   spain  plaza-de-castilla
# 2           1.740199      casa_de_campo  madrid   spain      casa-de-campo
# 23          1.458007   escuelas_aguirre  madrid   spain   escuelas-aguirre
# 31          1.553982  fernandez_ladreda  madrid   spain  fernandez-ladreda
# 45          0.841665     plaza_castilla  madrid   spain  plaza-de-castilla
# 38          1.743915      mendez_alvaro  madrid   spain      mendez-alvaro
# 24          1.174094   escuelas_aguirre  madrid   spain   escuelas-aguirre
# 3           1.459012      casa_de_campo  madrid   spain      casa-de-campo
# 17          1.126605     cuatro_caminos  madrid   spain     cuatro-caminos
# 10          1.174094         castellana  madrid   spain         castellana
# 25         -4.882004   escuelas_aguirre  madrid   spain   escuelas-aguirre
# 46         -5.204040     plaza_castilla  madrid   spain  plaza-de-castilla
# 4          -4.606002      casa_de_campo  madrid   spain      casa-de-campo
# 18         -4.928007     cuatro_caminos  madrid   spain     cuatro-caminos
# 32         -4.514007  fernandez_ladreda  madrid   spain  fernandez-ladreda
# 39         -4.330028      mendez_alvaro  madrid   spain      mendez-alvaro
# 11         -4.882004         castellana  madrid   spain         castellana
# 5          -1.382104      casa_de_campo  madrid   spain      casa-de-campo
# 40         -1.098613      mendez_alvaro  madrid   spain      mendez-alvaro
# 12         -1.665616         castellana  madrid   spain         castellana
# 33         -1.287605  fernandez_ladreda  madrid   spain  fernandez-ladreda
# 19         -1.712870     cuatro_caminos  madrid   spain     cuatro-caminos
# 26         -1.665616   escuelas_aguirre  madrid   spain   escuelas-aguirre
# 47         -1.996403     plaza_castilla  madrid   spain  plaza-de-castilla
# 13          4.000989         castellana  madrid   spain         castellana
# 34          4.378491  fernandez_ladreda  madrid   spain  fernandez-ladreda
# 41          4.567230      mendez_alvaro  madrid   spain      mendez-alvaro
# 6           4.284119      casa_de_campo  madrid   spain      casa-de-campo
# 20          3.953798     cuatro_caminos  madrid   spain     cuatro-caminos
# 27          4.000989   escuelas_aguirre  madrid   spain   escuelas-aguirre
# 48          3.670645     plaza_castilla  madrid   spain  plaza-de-castilla

# %%
weather_forecast_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 49 entries, 0 to 48
# Data columns (total 12 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   date                         49 non-null     datetime64[ns]
#  1   temperature_2m_mean          49 non-null     float32
#  2   precipitation_sum            49 non-null     float32
#  3   wind_speed_10m_max           49 non-null     float32
#  4   wind_direction_10m_dominant  49 non-null     float32
#  5   cloud_cover_max              49 non-null     float32
#  6   relative_humidity_2m_mean    49 non-null     float32
#  7   dew_point_2m_max             49 non-null     float32
#  8   sensor_id                    49 non-null     object
#  9   city                         49 non-null     object
#  10  country                      49 non-null     object
#  11  street                       49 non-null     object
# dtypes: datetime64[ns](1), float32(7), object(4)
# memory usage: 3.6+ KB

# %% [markdown]
# ## <span style="color:#ff5f27;">⬆️ Uploading new data to the Feature Store</span>

# %%
# Read historical air quality data
history_df = air_quality_fg.read()

history_df["date"] = pd.to_datetime(history_df["date"], utc=True).dt.tz_convert(None)

aq_today_df["date"] = pd.to_datetime(aq_today_df["date"], utc=True).dt.tz_convert(None)

processed_rows = []

for (country, city, street, sensor_id), df_today_sensor in aq_today_df.groupby(
    ["country", "city", "street", "sensor_id"]
):

    hist_sensor = history_df[
        (history_df["country"] == country) &
        (history_df["city"] == city) &
        (history_df["street"] == street) &
        (history_df["sensor_id"] == sensor_id)
    ].sort_values("date")

    last_days_sensor = hist_sensor.tail(3)

    df_window = pd.concat([last_days_sensor, df_today_sensor], ignore_index=True)

    df_window["date"] = pd.to_datetime(df_window["date"])

    df_window = util_2.add_lags_and_rolling(df_window)

    df_window["is_weekend"] = (df_window["date"].dt.weekday >= 5).astype(int)

    df_today_processed = df_window[df_window["date"].dt.date == pd.to_datetime(today).date()].copy()

    processed_rows.append(df_today_processed)

aq_today_processed = pd.concat(processed_rows, ignore_index=True)
# Out:
# Finished: Reading data from Hopsworks, using Hopsworks Feature Query Service (5.22s)

# %%
aq_today_df.dropna(inplace=True)
aq_today_df.reset_index(drop=True, inplace=True)
aq_today_processed.head(7)
# Out:
#         date  pm25          sensor_id    city country             street  \
# 0 2025-11-17  17.0      casa_de_campo  madrid   spain      casa-de-campo
# 1 2025-11-17  34.0         castellana  madrid   spain         castellana
# 2 2025-11-17  38.0     cuatro_caminos  madrid   spain     cuatro-caminos
# 3 2025-11-17  30.0   escuelas_aguirre  madrid   spain   escuelas-aguirre
# 4 2025-11-17  59.0  fernandez_ladreda  madrid   spain  fernandez-ladreda
# 5 2025-11-17  17.0      mendez_alvaro  madrid   spain      mendez-alvaro
# 6 2025-11-17  21.0     plaza_castilla  madrid   spain  plaza-de-castilla
#
#    pm25_lag1  pm25_lag2  pm25_lag3  pm25_roll3  is_weekend
# 0       25.0       13.0       15.0   18.333333           0
# 1       17.0       29.0       31.0   26.666667           0
# 2       25.0       11.0       17.0   24.666667           0
# 3       14.0       17.0       51.0   20.333333           0
# 4       23.0       33.0       62.0   38.333333           0
# 5       12.0       15.0       49.0   14.666667           0
# 6       13.0        9.0       15.0   14.333333           0

# %%
# Insert new data
air_quality_fg.insert(aq_today_processed)
# Out:
# 2025-11-17 20:56:25,388 INFO: 	1 expectation(s) included in expectation_suite.
# Validation succeeded.
# Validation Report saved successfully, explore a summary at https://c.app.hopsworks.ai:443/p/1271984/fs/1258583/fg/1718885
# Uploading Dataframe: 100.00% |██████████| Rows 7/7 | Elapsed Time: 00:00 | Remaining Time: 00:00
# Launching job: air_quality_madrid_1_offline_fg_materialization
# Job started successfully, you can follow the progress at
# https://c.app.hopsworks.ai:443/p/1271984/jobs/named/air_quality_madrid_1_offline_fg_materialization/executions
# (Job('air_quality_madrid_1_offline_fg_materialization', 'SPARK'),
#  {
#    "success": true,
#    "results": [
#      {
#        "success": true,
#        "expectation_config": {
#          "expectation_type": "expect_column_min_to_be_between",
#          "kwargs": {
#            "column": "pm25",
#            "min_value": -0.1,
#            "max_value": 500.0,
#            "strict_min": true
#          },
#          "meta": {
#            "expectationId": 759012
#          }
#        },
#        "result": {
#          "observed_value": 17.0,
#          "element_count": 7,
#          "missing_count": null,
#          "missing_percent": null
#        },
#        "meta": {
#          "ingestionResult": "INGESTED",
#          "validationTime": "2025-11-17T07:56:25.000388Z"
#        },
#        "exception_info": {
#          "raised_exception": false,
#          "exception_message": null,
#          "exception_traceback": null
#        }
#      }
#    ],
#    "evaluation_parameters": {},
#    "statistics": {
#      "evaluated_expectations": 1,
#      "successful_expectations": 1,
#      "unsuccessful_expectations": 0,
#      "success_percent": 100.0
#    },
#    "meta": {
#      "great_expectations_version": "0.18.12",
#      "expectation_suite_name": "aq_madrid_expectation_suite",
#      "run_id": {
#        "run_name": null,
#        "run_time": "2025-11-17T20:56:25.388277+01:00"
#      },
#      "batch_kwargs": {
#        "ge_batch_id": "7f9928d2-c3ef-11f0-b180-86c1d412d817"
#      },
#      "batch_markers": {},
#      "batch_parameters": {},
#      "validation_time": "20251117T195625.388084Z",
#      "expectation_suite_meta": {
#        "great_expectations_version": "0.18.12"
#      }
#    }
#  })

# %%
# Insert new data
weather_fg.insert(weather_forecast_df, wait=True)
# Out:
# 2025-11-17 20:57:12,878 INFO: 	2 expectation(s) included in expectation_suite.
# Validation succeeded.
# Validation Report saved successfully, explore a summary at https://c.app.hopsworks.ai:443/p/1271984/fs/1258583/fg/1718886
# Uploading Dataframe: 100.00% |██████████| Rows 49/49 | Elapsed Time: 00:01 | Remaining Time: 00:00
# Launching job: weather_madrid_sensors_1_offline_fg_materialization
# Job started successfully, you can follow the progress at
# https://c.app.hopsworks.ai:443/p/1271984/jobs/named/weather_madrid_sensors_1_offline_fg_materialization/executions
# 2025-11-17 20:57:30,404 INFO: Waiting for execution to finish. Current state: SUBMITTED. Final status: UNDEFINED
# 2025-11-17 20:57:33,602 INFO: Waiting for execution to finish. Current state: RUNNING. Final status: UNDEFINED
# 2025-11-17 20:59:25,422 INFO: Waiting for execution to finish. Current state: AGGREGATING_LOGS. Final status: SUCCEEDED
# 2025-11-17 20:59:25,593 INFO: Waiting for log aggregation to finish.
# 2025-11-17 20:59:37,568 INFO: Execution finished successfully.
# (Job('weather_madrid_sensors_1_offline_fg_materialization', 'SPARK'),
#  {
#    "success": true,
#    "results": [
#      {
#        "success": true,
#        "expectation_config": {
#          "expectation_type": "expect_column_min_to_be_between",
#          "kwargs": {
#            "column": "wind_speed_10m_max",
#            "min_value": -0.1,
#            "max_value": 1000.0,
#            "strict_min": true
#          },
#          "meta": {
#            "expectationId": 759014
#          }
#        },
#        "result": {
#          "observed_value": 1.6099690198898315,
#          "element_count": 49,
#          "missing_count": null,
#          "missing_percent": null
#        },
#        "meta": {
#          "ingestionResult": "INGESTED",
#          "validationTime": "2025-11-17T07:57:12.000878Z"
#        },
#        "exception_info": {
#          "raised_exception": false,
#          "exception_message": null,
#          "exception_traceback": null
#        }
#      },
#      {
#        "success": true,
#        "expectation_config": {
#          "expectation_type": "expect_column_min_to_be_between",
#          "kwargs": {
#            "column": "precipitation_sum",
#            "min_value": -0.1,
#            "max_value": 1000.0,
#            "strict_min": true
#          },
#          "meta": {
#            "expectationId": 759013
#          }
#        },
#        "result": {
#          "observed_value": 0.0,
#          "element_count": 49,
#          "missing_count": null,
#          "missing_percent": null
#        },
#        "meta": {
#          "ingestionResult": "INGESTED",
#          "validationTime": "2025-11-17T07:57:12.000878Z"
#        },
#        "exception_info": {
#          "raised_exception": false,
#          "exception_message": null,
#          "exception_traceback": null
#        }
#      }
#    ],
#    "evaluation_parameters": {},
#    "statistics": {
#      "evaluated_expectations": 2,
#      "successful_expectations": 2,
#      "unsuccessful_expectations": 0,
#      "success_percent": 100.0
#    },
#    "meta": {
#      "great_expectations_version": "0.18.12",
#      "expectation_suite_name": "weather_expectation_suite",
#      "run_id": {
#        "run_name": null,
#        "run_time": "2025-11-17T20:57:12.878213+01:00"
#      },
#      "batch_kwargs": {
#        "ge_batch_id": "9be8323a-c3ef-11f0-b180-86c1d412d817"
#      },
#      "batch_markers": {},
#      "batch_parameters": {},
#      "validation_time": "20251117T195712.878080Z",
#      "expectation_suite_meta": {
#        "great_expectations_version": "0.18.12"
#      }
#    }
#  })

# %% [markdown]
# ## <span style="color:#ff5f27;">⏭️ **Next:** Part 03: Training Pipeline
#  </span>
#
# In the following notebook you will read from a feature group and create training dataset within the feature store
